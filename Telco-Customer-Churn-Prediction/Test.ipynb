# %%
from flask import Flask, render_template,request,url_for
import pandas as pd
import pickle
app =Flask(__name__)

# %%
df =pd.read_csv("first_telc.csv")
df.head(5)
# Out:
#    Unnamed: 0  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0           0  Female              0     Yes         No       1           No
# 1           1    Male              0      No         No      34          Yes
# 2           3    Male              0      No         No      45           No
# 3           6    Male              0      No        Yes      22          Yes
# 4          11    Male              0      No         No      16          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0  No phone service             DSL                   No                  Yes
# 1                No             DSL                  Yes                   No
# 2  No phone service             DSL                  Yes                   No
# 3               Yes     Fiber optic                   No                  Yes
# 4                No              No  No internet service  No internet service
#
# ...

# %%
df.drop(columns=['Unnamed: 0'])
# Out:
#     gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   Female              0     Yes         No       1           No
# 1     Male              0      No         No      34          Yes
# 2     Male              0      No         No      45           No
# 3     Male              0      No        Yes      22          Yes
# 4     Male              0      No         No      16          Yes
# ..     ...            ...     ...        ...     ...          ...
# 70  Female              0     Yes         No      51          Yes
# 71  Female              0      No         No      26           No
# 72  Female              0     Yes        Yes       0           No
# 73    Male              0     Yes        Yes      39          Yes
# 74    Male              1      No         No       1           No
#
#        MultipleLines InternetService       OnlineSecurity  \
# 0   No phone service             DSL                   No
# ...

# %%
input1 = 0
input2 = 29.85
input3 = 29.85
input4 = 'Female'
input5 = "Yes"
input6 = "No"
input7 = "No"
input8 = "No phone service"
input9 = "DSL"
input10 = "No"
input11 = "Yes"
input12 = "No"
input13 = "No"
input14 = "No"
input15 = "No"
input16 = "Month-to-month"
input17 = "Yes"
input18 = "Electronic check"
input19 =1

# %%
data =[[input1,input2,input3,input4, input5,input6,input7,input8,input9, input10,input11,input12,input13,input14, input15,input16,input17,input18,input19]]
data
# Out:
# [[0,
#   29.85,
#   29.85,
#   'Female',
#   'Yes',
#   'No',
#   'No',
#   'No phone service',
#   'DSL',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Month-to-month',
#   'Yes',
#   'Electronic check',
#   1]]

# %%
df1 =pd.DataFrame(data,columns=['SeniorCitizen', 'MonthlyCharges', 'TotalCharges', 'gender', 
                                           'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',
                                           'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                                           'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
                                           'PaymentMethod', 'tenure'])
df1
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  gender Partner Dependents  \
# 0              0           29.85         29.85  Female     Yes         No
#
#   PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0           No  No phone service             DSL             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  tenure
# 0              Yes  Electronic check       1

# %%
new_df=pd.concat([df,df1], ignore_index =True)
new_df
# Out:
#     Unnamed: 0  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0          0.0  Female              0     Yes         No       1           No
# 1          1.0    Male              0      No         No      34          Yes
# 2          3.0    Male              0      No         No      45           No
# 3          6.0    Male              0      No        Yes      22          Yes
# 4         11.0    Male              0      No         No      16          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 71       435.0  Female              0      No         No      26           No
# 72       488.0  Female              0     Yes        Yes       0           No
# 73       546.0    Male              0     Yes        Yes      39          Yes
# 74        20.0    Male              1      No         No       1           No
# 75         NaN  Female              0     Yes         No       1           No
#
# ...

# %%
labels =['{0} - {1}'.format(i, i+11) for i in range(1,72,12)]
df['tenure_group'] = pd.cut(df.tenure.astype(int), range(1,80,12), right=False, labels =labels)
df['tenure_group']
# Out:
# 0      1 - 12
# 1     25 - 36
# 2     37 - 48
# 3     13 - 24
# 4     13 - 24
#        ...
# 70    49 - 60
# 71    25 - 36
# 72        NaN
# 73    37 - 48
# 74     1 - 12
# Name: tenure_group, Length: 75, dtype: category
# Categories (6, object): ['1 - 12' < '13 - 24' < '25 - 36' < '37 - 48' < '49 - 60' < '61 - 72']

# %%
new_df.drop(columns=['tenure'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 new_df.drop(columns=['tenure'])
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
new_df['SeniorCitizen'] = pd.to_numeric(new_df.SeniorCitizen)
new_df['MonthlyCharges'] = pd.to_numeric(new_df.MonthlyCharges)
new_df['TotalCharges'] = pd.to_numeric(new_df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 new_df['SeniorCitizen'] = pd.to_numeric(new_df.SeniorCitizen)
#       2 new_df['MonthlyCharges'] = pd.to_numeric(new_df.MonthlyCharges)
#       3 new_df['TotalCharges'] = pd.to_numeric(new_df.TotalCharges)
#
# AttributeError: 'NoneType' object has no attribute 'SeniorCitizen'

# %%
new_df_dummies =pd.get_dummies(new_df[['gender', 'SeniorCitizen','MonthlyCharges', 'TotalCharges', 'Partner', 'Dependents', 'PhoneService',
           'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
           'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
           'Contract', 'PaperlessBilling', 'PaymentMethod','tenure_group']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 new_df_dummies =pd.get_dummies(new_df[['gender', 'SeniorCitizen','MonthlyCharges', 'TotalCharges', 'Partner', 'Dependents', 'PhoneService',
#       2            'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#       3            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#       4            'Contract', 'PaperlessBilling', 'PaymentMethod','tenure_group']])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
model = pickle.load(open("modeldt.sav", "rb"))
single = model.predict(new_df_dummies .tail(1))
if single == 1:
	o = "This Customer is churned"
    print(o)
else:
	o = "This Customer is not churned"
    print(o)
# Out:
#   File <tokenize>:5
#     print(o)
#     ^
# IndentationError: unindent does not match any outer indentation level
